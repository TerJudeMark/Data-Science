# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Jude Ter Mark**
#
# I want to be a Petroleum Engineer

# %% [markdown]
# *I am interested in Data Science because I want to increase my chances of getting employed and remaining valuable in the Oil and Gas Industry. I want to use Data to ensure quality Decision making in which ever company or organization I find myself.*

# %% [markdown]
# ### My code will do the multiplication between two or more numbers ###

# %%
a = 6
b = 2
c = 2

print(a*b*c)
# Out:
# 24

# %% [markdown]
# ### Horizontal rule
# ***
# ### Bullet list
# * One
# * Two
# * Three
# * Four
# * Five
#
# ### Number list
# 1. One
# 2. Two
# 3. Three
# 4. Four
# 5. Five
#
#
#
# ### Tables
# |Country|State|
# |------|------|
# |Nigeria|Nasarawa|
# |Ghana|Accra|
# |South Africa|Johanesburge|
#
# |state|capital|
# |----|----|
# |Rivers|Port Harcourt|
# |Cross River|Calabar|
# |Nasarawa|Lafia|
#
# ### Hyperlinks
# [God bless me in my Data Science journey](https://www.ibm.com "visit to learn more")
#
# ### Images
# ![IMG-20230218-WA0026.jpg](attachment:094a2d05-7226-4a06-8164-7d59b14c17e9.jpg)
#
# ### Code highlighting (1)
# `My name is Ter Jude Mark`
#
# ### code highlighting (2)
# <code> python
#     my name is Ter Jude Mark
# </code>
#
# ### Synthax highlighting
# ``` python
# my name is Ter Jude Mark
# ```
#
# ### Blocked Quotes
# > My name is Ter Jude Mark
# >
# > I want to learn Data Science
#
# ### strike through text
# ~Master~
